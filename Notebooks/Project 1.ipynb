# %%
import pandas as pd
from pathlib import Path
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from dotenv import load_dotenv
import seaborn as sns

# %%
file_path_1 = Path('coin_Bitcoin.csv')
bitcoin_df  = pd.read_csv(file_path_1)

# %%
bitcoin_df.head()
# Out:
#    SNo     Name Symbol        Date        High         Low        Open  \
# 0  978  Bitcoin    BTC  2016-01-01  436.246002  427.515015  430.721008
# 1  979  Bitcoin    BTC  2016-01-02  436.062012  431.869995  434.622009
# 2  980  Bitcoin    BTC  2016-01-03  433.743012  424.705994  433.578003
# 3  981  Bitcoin    BTC  2016-01-04  434.516998  429.084015  430.061005
# 4  982  Bitcoin    BTC  2016-01-05  434.182007  429.675995  433.069000
#
#         Close      Volume     Marketcap
# 0  434.334015  36278900.0  6.529300e+09
# 1  433.437988  30096600.0  6.517390e+09
# 2  430.010986  39633800.0  6.467430e+09
# 3  433.091003  38477500.0  6.515713e+09
# 4  431.959992  34522600.0  6.500393e+09

# %%
file_path_2 = Path('coin_Ethereum.csv')
ethereum_df = pd.read_csv(file_path_2)

# %%
ethereum_df.head()
# Out:
#    SNo      Name Symbol        Date      High       Low      Open     Close  \
# 0  147  Ethereum    ETH  2016-01-01  0.954822  0.931442  0.933712  0.948024
# 1  148  Ethereum    ETH  2016-01-02  0.969637  0.936560  0.947401  0.937124
# 2  149  Ethereum    ETH  2016-01-03  0.991362  0.934313  0.938430  0.971905
# 3  150  Ethereum    ETH  2016-01-04  0.976438  0.929835  0.972045  0.954480
# 4  151  Ethereum    ETH  2016-01-05  0.970597  0.946543  0.953147  0.950176
#
#    Volume    Marketcap
# 0  206062  71980386.46
# 1  255504  71176658.05
# 2  407632  73843291.67
# 3  346245  72543706.62
# 4  219833  72240974.34

# %%
file_path_3 = Path('coin_Litecoin.csv')
litecoin_df = pd.read_csv(file_path_3)

# %%
litecoin_df.head()
# Out:
#    SNo      Name Symbol      Date     High      Low     Open    Close  \
# 0  978  Litecoin    LTC  1/1/2016  3.53102  3.46925  3.47952  3.50898
# 1  979  Litecoin    LTC  1/2/2016  3.52712  3.49219  3.51528  3.50216
# 2  980  Litecoin    LTC  1/3/2016  3.50643  3.45086  3.50400  3.48307
# 3  981  Litecoin    LTC  1/4/2016  3.50723  3.47615  3.47910  3.49539
# 4  982  Litecoin    LTC  1/5/2016  3.50819  3.45372  3.49200  3.46967
#
#       Volume    Marketcap
# 0  2791170.0  153910742.1
# 1  3020260.0  153658445.0
# 2  2406150.0  152873557.1
# 3  3309740.0  153467941.9
# 4  2104650.0  152390642.7

# %%
file_path_4 = Path('coin_XRP.csv')
xrp_df = pd.read_csv(file_path_4)

# %%
xrp_df.head()
# Out:
#    SNo Name Symbol        Date      High       Low      Open     Close  \
# 0  880  XRP    XRP  2016-01-01  0.006044  0.005933  0.006040  0.005955
# 1  881  XRP    XRP  2016-01-02  0.006079  0.005933  0.005957  0.006065
# 2  882  XRP    XRP  2016-01-03  0.006070  0.005988  0.006066  0.006017
# 3  883  XRP    XRP  2016-01-04  0.006059  0.005953  0.006019  0.005958
# 4  884  XRP    XRP  2016-01-05  0.006044  0.005953  0.005954  0.006044
#
#      Volume    Marketcap
# 0  211767.0  199716460.9
# 1  278539.0  203395182.7
# 2  291723.0  201799471.3
# 3  310820.0  199807682.8
# 4  381554.0  202711354.3

# %%
# Find the Difference Between Highest and Lowest Prices 
# Which coin had biggest difference between min and max level?

# %%
xrp_df.describe()
# Out:
#                SNo         High          Low         Open        Close  \
# count  1885.000000  1885.000000  1885.000000  1885.000000  1885.000000
# m
# count  1.885000e+03  1.885000e+03
# mean   5.850077e+09  2.907151e+10
# std    8.260745e+09  3.386433e+10
# min    2.060620e+05  7.117666e+07
# 25%    1.456020e+08  4.553738e+09
# 50%    2.208720e+09  2.089154e+10
# 75%    8.446546e+09  3.675680e+10
# max    6.073363e+10  2.249100e+11

# %%
# Histogram
# The Histogram shows the frequency in which each market indicator was at for a certain amount or time

# %%
bitcoin_df.hist(bins=30, figsize=(15,10), color='b', linestyle='dashed',linewidth=2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000010FF2EB3280>,
# ...
#       dtype=object)

# %%
# Visualize the CLosing Prices with the Volume and the Marketcap 
# A higher marketcap volume ratio means the more undervalued the coin may be

# %%
bitcoin_df.plot(grid=True, figsize=(10, 5)).axhline(y = 1, color = "black", lw = 2)

# %%
ethereum_df.plot(grid=True, figsize=(10, 5)).axhline(y = 1, color = "black", lw = 2)

# %%
litecoin_df.plot(grid=True, figsize=(10, 5)).axhline(y = 1, color = "black", lw = 2)

# %%
xrp_df.plot(grid=True, figsize=(10, 5)).axhline(y = 1, color = "black", lw = 2)

# %%
# Closing Prices Move in Tandem

# %%
fig, ax1 = plt.subplots(figsize=(20, 10))
ax2 = ax1.twinx()
rspine = ax2.spines['right']
rspine.set_position(('axes', 1.15))
ax2.set_frame_on(True)
ax2.patch.set_visible(False)
fig.subplots_adjust(right=0.7)
bitcoin_df.plot(ax=ax1, style='b-')
ethereum_df.plot(ax=ax1, style='r-', secondary_y=True)
litecoin_df.plot(ax=ax2, style='g-')
xrp_df.plot(ax=ax2, style='y-')
# legend
ax2.legend([ax1.get_lines()[0],ax1.right_ax.get_lines()[0],ax2.get_lines()[0]], ['BTC', 'ETH', 'LTC', 'XRP'])

# %%
# Buy and Hold Strategy
# Buy and hold strategy is a passive investment strategy in which an investor holds for a long period of time.

# %%
bitcoin_df_return = bitcoin_df.apply(lambda x: x / x[0])
bitcoin_df_return.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# ~\anaconda\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# ~\anaconda\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
# Extract Closing Prices

# %%
df = pd.DataFrame({'BTC': df_btc.close,
                   'ETH': df_eth.close,
                   'LTC': df_ltc.close
                    'XRP': df_xrp.close})
df.head()
# Out:
#   File "<ipython-input-257-549c1b57b12c>", line 4
#     'XRP': df_xrp.close})
#     ^
# SyntaxError: invalid syntax

# %%
# Compute the correlation matrix for Bitcoin 
corr = bitcoin_df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, annot=True, fmt = '.4f', mask=mask, center=0, square=True, linewidths=.5)

# %%
# Compute the correlation matrix for Ethereum
# When the price of Bitcoin closed high, so did the other cryptocurrencies.

corr = ethereum_df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, annot=True, fmt = '.4f', mask=mask, center=0, square=True, linewidths=.5)

# %%
# Compute the correlation matrix for Litecoin
corr = litecoin_df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, annot=True, fmt = '.4f', mask=mask, center=0, square=True, linewidths=.5)

# %%
# Compute the correlation matrix for XRP
corr = xrp_df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, annot=True, fmt = '.4f', mask=mask, center=0, square=True, linewidths=.5)

# %%
# Using this Pearson Correlation, we show that Bitcoin heavily correlates to Ethereum, Litecoin, and XRP closing prices.

# %%
# Use Box Plots for Volume and Marketcap
# The higher the correlation between marketcap and volume, the more undervalued the coin.

ax = sns.boxplot(data=bitcoin_df, orient="h")

# %%
ax = sns.boxplot(data=ethereum_df, orient="h")

# %%
ax = sns.boxplot(data=litecoin_df, orient="h")

# %%
ax = sns.boxplot(data=xrp_df, orient="h")
